# %%
data = []
for line in open('passing_cleaned.csv'):
    current_line = line.strip().split(',')
    data.append(current_line)

# %%
data[1]
# Out:
# ['0',
#  'Kurt Warner',
#  'STL',
#  '30',
#  '16',
#  '16',
#  '375',
#  '546',
#  '68.7',
#  '4830',
#  '36',
#  '6.6',
#  '22',
#  '4.0',
#  '233',
#  '65',
#  '8.8',
#  '8.4',
#  '12.9',
#  '301.9',
#  '101.4',
#  '38',
#  '233',
#  '6.5',
#  '7.87',
#  '7.41',
#  '2001']

# %%
for line in data[1:]:
    GS = line[5:6]
    if int(GS[0]) >= 8:
        print(GS)

        # is.numbers (just need to remove first value)
# Out:
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['15']
# ['15']
# ['16']
# ['16']
# ['15']
# ['16']
# ['16']
# ['14']
# ['15']
# ['14']
# ['14']
# ['15']
# ['16']
# ['11']
# ['9']
# ['14']
# ['13']
# ['8']
# ['12']
# ['8']
# ['8']
# ['14']
# ['16']
# ['16']
# ['16']
# ['11']
# ['16']
# ['16']
# ['16']
# ['16']
# ['14']
# ['16']
# ['9']
# ['13']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['13']
# ['12']
# ['12']
# ['10']
# ['13']
# ['16']
# ['15']
# ['14']
# ['11']
# ['15']
# ['14']
# ['16']
# ['12']
# ['10']
# ['10']
# ['10']
# ['8']
# ['9']
# ['16']
# ['14']
# ['15']
# ['15']
# ['16']
# ['15']
# ['14']
# ['15']
# ['15']
# ['16']
# ['14']
# ['14']
# ['16']
# ['9']
# ['16']
# ['16']
# ['16']
# ['15']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['14']
# ['16']
# ['16']
# ['16']
# ['15']
# ['16']
# ['14']
# ['13']
# ['16']
# ['16']
# ['13']
# ['13']
# ...
