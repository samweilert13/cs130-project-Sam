# %%
data = []
for line in open('passing_cleaned.csv'):
    current_line = line.strip().split(',')
    data.append(current_line)

# %%
data[1]
# Out:
# ['0',
#  'Kurt Warner',
#  'STL',
#  '30',
#  '16',
#  '16',
#  '375',
#  '546',
#  '68.7',
#  '4830',
#  '36',
#  '6.6',
#  '22',
#  '4.0',
#  '233',
#  '65',
#  '8.8',
#  '8.4',
#  '12.9',
#  '301.9',
#  '101.4',
#  '38',
#  '233',
#  '6.5',
#  '7.87',
#  '7.41',
#  '2001']

# %%
import pandas as pd
import numpy as np
passing_stats = pd.read_csv("Data.csv")
print(passing_stats)
# Out:
#       Unnamed: 0          Player   Tm  Age   G  GS  Cmp  Att   Cmp%   Yds  \
# 0              0     Kurt Warner  STL   30  16  16  375  546   68.7  4830
# 1              1  Peyton Manning  IND   25  16  16  343  547   62.7  4131
# 2              2     Brett Favre  GNB   32  16  16  314  510   61.6  3921
# 3              3    Aaron Brooks  NOR   25  16  16  312  558   55.9  3832
# 4              4     Rich Gannon  OAK   36  16  16  361  549   65.8  3828
# ...          ...             ...  ...  ...  ..  ..  ...  ...    ...   ...
# 2345        2389  Kadarius Toney  KAN   24  13   2    0    1    0.0     0
# 2346        2390      Kyle Trask  TAM   25   2   0    0    1    0.0     0
# 2347        2391  Garrett Wilson  NYJ   23  17  17    0    1    0.0     0
# 2348        2392  Christian Kirk  JAX   27  12  12    1    2   50.0    -1
# 2349        2393   Ja'Marr Chase  CIN   23  16  16    1    1  100.0    -7
#
#       ...  AY/A   Y/C    Y/G   Rate  Sk  Yds-s  Sk%  NY/A  ANY/A  Year
# ...

# %%
passing_stats.iloc[10] #selecting rows
# Out:
# Unnamed: 0              10
# Player        Brad Johnson
# Tm                     TAM
# Age                     33
# G                       16
# GS                      16
# Cmp                    340
# Att                    559
# Cmp%                  60.8
# Yds                   3406
# TD                      13
# TD%                    2.3
# Int                     11
# Int%                   2.0
# 1D                     181
# Lng                     47
# Y/A                    6.1
# AY/A                   5.7
# Y/C                   10.0
# Y/G                  212.9
# Rate                  77.7
# Sk                      44
# Yds-s                  269
# Sk%                    7.3
# NY/A                   5.2
# ANY/A                 4.81
# Year                  2001
# Name: 10, dtype: object

# %%
print(passing_stats.iloc[10,9])
# Out:
# 3406

# %%
passing_stats.iloc[:10,9]
# Out:
# 0    4830
# 1    4131
# 2    3921
# 3    3832
# 4    3828
# 5    3783
# 6    3764
# 7    3653
# 8    3538
# 9    3464
# Name: Yds, dtype: int64

# %%
passing_stats.loc[passing_stats.Yds > 4000] #shows yards
# Out:
#       Unnamed: 0           Player   Tm  Age   G  GS  Cmp  Att  Cmp%   Yds  \
# 0              0      Kurt Warner  STL   30  16  16  375  546  68.7  4830
# 1              1   Peyton Manning  IND   25  16  16  343  547  62.7  4131
# 107          109      Rich Gannon  OAK   37  16  16  418  618  67.6  4689
# 108          110     Drew Bledsoe  BUF   30  16  16  375  610  61.5  4359
# 109          111   Peyton Manning  IND   26  16  16  392  591  66.3  4200
# ...          ...              ...  ...  ...  ..  ..  ...  ...   ...   ...
# 2251        2293  Patrick Mahomes  KAN   28  16  16  401  597  67.2  4183
# 2252        2294      Jordan Love  GNB   25  17  17  372  579  64.2  4159
# 2253        2295      C.J. Stroud  HOU   22  15  15  319  499  63.9  4108
# 2254        2296   Baker Mayfield  TAM   28  17  17  364  566  64.3  4044
# 2255        2297  Trevor Lawrence  JAX   24  16  16  370  564  65.6  4016
#
#       ...  AY/A   Y/C    Y/G   Rate  Sk  Yds-s  Sk%  NY/A  ANY/A  Year
# ...

# %%
passing_stats2001 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.G >= 15) & (passing_stats.Year == 2001)] #combining

# %%
passing_stats.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Tm', 'Age', 'G', 'GS', 'Cmp', 'Att', 'Cmp%',
#        'Yds', 'TD', 'TD%', 'Int', 'Int%', '1D', 'Lng', 'Y/A', 'AY/A', 'Y/C',
#        'Y/G', 'Rate', 'Sk', 'Yds-s', 'Sk%', 'NY/A', 'ANY/A', 'Year'],
#       dtype='object')

# %%
passing_stats['average_yds_per_start'] = passing_stats['Yds'] / passing_stats['GS']

# %%
passing_stats2001 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2001)] #combinin
passing_stats2002 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2002)] #combinin
passing_stats2003 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2003)] #combinin
passing_stats2004 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2004)] #combinin
passing_stats2005 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2005)] #combinin
passing_stats2006 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2006)] #combinin
passing_stats2008 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2008)] #combinin
passing_stats2009 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2009)] #combinin
passing_stats2010 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2010)] #combinin
passing_stats2011 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2011)] #combinin
passing_stats2012 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2012)] #combinin
passing_stats2013 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2013)] #combinin
passing_stats2014 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2014)] #combinin
passing_stats2015 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2015)] #combinin
passing_stats2016 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2016)] #combinin
passing_stats2017 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2017)] #combinin
passing_stats2018 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2018)] #combinin
passing_stats2019 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2019)] #combinin
passing_stats2020 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2020)] #combinin
passing_stats2021 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2021)] #combinin
passing_stats2022 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2022)] #combinin
passing_stats2023 = passing_stats.loc[(passing_stats.Yds > 1000) & (passing_stats.GS >= 14) & (passing_stats.Year == 2023)] #combinin

# %%
import matplotlib.pyplot as plt #This is the API to matplotlib

# %%
passing_stats2001.Yds
# Out:
# 0     4830
# 1     4131
# 2     3921
# 3     3832
# 4     3828
# 5     3783
# 6     3764
# 7     3653
# 8     3538
# 9     3464
# 10    3406
# 11    3350
# 12    3309
# 13    3290
# 14    3233
# 15    3216
# 16    3109
# 17    3040
# 18    3033
# 19    2931
# 20    2847
# 21    2843
# 22    2827
# 23    2752
# 26    2386
# Name: Yds, dtype: int64

# %%
passing_stats2002.Yds
# Out:
# 107    4689
# 108    4359
# 109    4200
# 110    4073
# 111    3853
# 112    3764
# 113    3690
# 114    3658
# 115    3572
# 116    3387
# 117    3344
# 118    3284
# 124    2972
# 125    2936
# 126    2842
# 128    2788
# 129    2630
# 130    2592
# Name: Yds, dtype: int64

# %%
passing_stats2001.Yds.plot(kind='hist')
plt.title('Passing Stats in 2001')
plt.xlabel('Yds')
plt.show()

# %%
passing_stats2001.plot(kind='scatter', x='Tm', y='Yds', figsize=(8,4), s=1)
plt.title('Passing Stats in 2001')
plt.xlabel('Team')
plt.ylabel('Yds')
plt.show()

# %%
passing_stats2002.plot(kind='scatter', x='Player', y='Yds')
plt.title('Passing Stats in 2002')
plt.xlabel('Player name')
plt.ylabel('Yds')
plt.show()

# %%
print(passing_stats2001.Yds.mean())
print(passing_stats2002.Yds.mean())
print(passing_stats2003.Yds.mean())
print(passing_stats2004.Yds.mean())
print(passing_stats2005.Yds.mean())
print(passing_stats2006.Yds.mean())
print(passing_stats2008.Yds.mean())
print(passing_stats2009.Yds.mean())
print(passing_stats2010.Yds.mean())
print(passing_stats2011.Yds.mean())
print(passing_stats2012.Yds.mean())
print(passing_stats2013.Yds.mean())
print(passing_stats2014.Yds.mean())
print(passing_stats2015.Yds.mean())
print(passing_stats2016.Yds.mean())
print(passing_stats2017.Yds.mean())
print(passing_stats2018.Yds.mean())
print(passing_stats2019.Yds.mean())
print(passing_stats2020.Yds.mean())
print(passing_stats2021.Yds.mean())
print(passing_stats2022.Yds.mean())
print(passing_stats2023.Yds.mean())
# Out:
# 3372.64
# 3479.6111111111113
# 3500.3529411764707
# 3613.9473684210525
# 3363.6666666666665
# 3469.1666666666665
# 3525.181818181818
# 3808.5
# 3733.3888888888887
# 4019.157894736842
# 3914.84
# 4054.6315789473683
# 4049.05
# 4092.4761904761904
# 4013.88
# 3657.1304347826085
# 4208.263157894737
# 3965.05
# 3999.3809523809523
# 3987.0416666666665
# 3872.0
# 3983.722222222222

# %%
means = [
    3410.2608695652175,
    3479.6111111111113,
    3500.3529411764707,
    3613.9473684210525,
    3363.6666666666665,
    3469.1666666666665,
    3525.181818181818,
    3808.5,
    3733.3888888888887,
    4019.157894736842,
    3914.84,
    4054.6315789473683,
    4049.05,
    4092.4761904761904,
    4013.88,
    3657.1304347826085,
    4208.263157894737,
    3965.05,
    3999.3809523809523,
    3987.0416666666665,
    3872.0,
    3983.722222222222
]

years = list(range(2001, 2024))

passing_stats_mean = {year: mean for year, mean in zip(years, means)}

# %%
df_yards = pd.DataFrame({
    "Year": list(passing_stats_mean.keys()),
    "MeanYards": list(passing_stats_mean.values())
}) #this turns that dictionary into a dataframe

# %%
df_yards.plot(kind='scatter', x='Year', y='MeanYards')
plt.title('Average yards per year')
plt.xlabel('Year')
plt.ylabel('Yards')
plt.show()

# %%
x = df_yards["Year"]
y = df_yards["MeanYards"]

m, b = np.polyfit(x, y, 1)  #I'm trying to find a line of best fit for how the data changed over time so I use the linear formula y = mx + b


plt.scatter(x, y)
plt.plot(x, m*x + b)
plt.title('Average yards per year')
plt.xlabel('Year')
plt.ylabel('Yards')
plt.show()

# %%
print(passing_stats2001.TD.mean())
print(passing_stats2002.TD.mean())
print(passing_stats2003.TD.mean())
print(passing_stats2004.TD.mean())
print(passing_stats2005.TD.mean())
print(passing_stats2006.TD.mean())
print(passing_stats2008.TD.mean())
print(passing_stats2009.TD.mean())
print(passing_stats2010.TD.mean())
print(passing_stats2011.TD.mean())
print(passing_stats2012.TD.mean())
print(passing_stats2013.TD.mean())
print(passing_stats2014.TD.mean())
print(passing_stats2015.TD.mean())
print(passing_stats2016.TD.mean())
print(passing_stats2017.TD.mean())
print(passing_stats2018.TD.mean())
print(passing_stats2019.TD.mean())
print(passing_stats2020.TD.mean())
print(passing_stats2021.TD.mean())
print(passing_stats2022.TD.mean())
print(passing_stats2023.TD.mean())
# Out:
# 19.88
# 20.833333333333332
# 22.294117647058822
# 24.473684210526315
# 20.833333333333332
# 20.38888888888889
# 19.954545454545453
# 24.272727272727273
# 25.22222222222222
# 26.105263157894736
# 24.56
# 26.94736842105263
# 27.85
# 27.952380952380953
# 24.64
# 22.434782608695652
# 28.842105263157894
# 25.05
# 28.714285714285715
# 26.75
# 24.61111111111111
# 25.555555555555557

# %%
td_values = [
    19.88,
    20.833333333333332,
    22.294117647058822,
    24.473684210526315,
    20.833333333333332,
    20.38888888888889,
    19.954545454545453,
    24.272727272727273,
    25.22222222222222,
    26.105263157894736,
    24.56,
    26.94736842105263,
    27.85,
    27.952380952380953,
    24.64,
    22.434782608695652,
    28.842105263157894,
    25.05,
    28.714285714285715,
    26.75,
    24.61111111111111,
    25.555555555555557
]

years = list(range(2001, 2023))

# %%
df_td = pd.DataFrame({
    "Year": years,
    "TDs": td_values
})

# %%
df_td.plot(kind='scatter', x='Year', y='TDs')
plt.title('Average TDs per year')
plt.xlabel('Year')
plt.ylabel('TDs')
plt.show()

# %%
x = df_td["Year"]
y = df_td["TDs"]

m, b = np.polyfit(x, y, 1)  #I'm trying to find a line of best fit for how the data changed over time so I use the linear formula y = mx + b


plt.scatter(x, y)
plt.plot(x, m*x + b)
plt.title('Average TDs per year')
plt.xlabel('Year')
plt.ylabel('TDs')
plt.show()

# %%
BUF_stats = passing_stats.loc[(passing_stats.Yds > 100) & (passing_stats.Tm == "BUF") & (passing_stats.Year != 2007)] #find team specific
print(BUF_stats[["Player", "Tm", "Age", "GS", "Yds", "TD", "Year"]])
# Out:
#                 Player   Tm  Age  GS   Yds  TD  Year
# 28       Alex Van Pelt  BUF   31   8  2056  12  2001
# 30         Rob Johnson  BUF   28   8  1465   5  2001
# 49        Travis Brown  BUF   24   0   201   1  2001
# 108       Drew Bledsoe  BUF   30  16  4359  24  2002
# 231       Drew Bledsoe  BUF   31  16  2860  11  2003
# 269       Travis Brown  BUF   26   0   160   0  2003
# 352       Drew Bledsoe  BUF   32  16  2932  20  2004
# 483      Kelly Holcomb  BUF   32   8  1509  10  2005
# 484        J.P. Losman  BUF   24   8  1340   8  2005
# 560        J.P. Losman  BUF   25  16  3051  19  2006
# 772      Trent Edwards  BUF   25  14  2699  11  2008
# 790        J.P. Losman  BUF   27   2   584   2  2008
# 882   Ryan Fitzpatrick  BUF   27   8  1422   9  2009
# 886      Trent Edwards  BUF   26   7  1169   6  2009
# 907        Brian Brohm  BUF   24   1   146   0  2009
# 982   Ryan Fitzpatrick  BUF   28  13  3000  23  2010
# 1024       Brian Brohm  BUF   25   1   106   0  2010
# ...

# %%
passing_stats = pd.read_csv("data.csv")

BUF_stats = passing_stats.loc[(passing_stats.Yds > 100) & (passing_stats.GS >= 1) & (passing_stats.Tm == "BUF") & (passing_stats.Year != 2007)]

# %%
BUF_yards_per_year = BUF_stats.groupby("Year")["Yds"].sum().reset_index() # Group by Year and sum Yds for all players in that year

# %%
BUF_yards_per_year.plot(kind='scatter', x='Year', y='Yds')
plt.title('Bills passing Stats')
plt.xlabel('Year')
plt.ylabel('Yds')
plt.show()

# %%
x = BUF_yards_per_year["Year"]
y = BUF_yards_per_year["Yds"]

m, b = np.polyfit(x, y, 1)

plt.scatter(x, y)
plt.plot(x, m*x + b)
plt.title("BUF Passing Yards Per Season with Trendline")
plt.xlabel("Year")
plt.ylabel("Total Yards")
plt.show()

# %%
BUF_TD_per_year = buf_stats.groupby("Year")["TD"].sum().reset_index() # Group by Year and sum Yds for all players in that year

# %%
BUF_TD_per_year.plot(kind='scatter', x='Year', y='TD')
plt.title('Bills TD Stats')
plt.xlabel('Year')
plt.ylabel('TDs')
plt.show()

# %%
x = BUF_yards_per_year["Year"]
y = BUF_yards_per_year["TD"]

m, b = np.polyfit(x, y, 1)

plt.scatter(x, y)
plt.plot(x, m*x + b)
plt.title("BUF Passing Yards Per Season with Trendline")
plt.xlabel("Year")
plt.ylabel("Total Yards")
plt.show()
